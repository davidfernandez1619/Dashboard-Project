# %%
import os

current_directory = os.getcwd()
print(current_directory)


import pandas as pd
# Out:
# /Users/davidfernandez/Desktop/Projects/Dashboard-Project/Notebooks

# %%
psy = pd.read_csv('/Users/davidfernandez/Desktop/Projects/Dashboard-Project/Data/cleaned_psy.csv')

psy
# Out:
#           Country Code  Year  Schizophrenia (%)  Bipolar disorder (%)  \
# 0     Afghanistan  AFG  1990           0.160560              0.697779
# 1     Afghanistan  AFG  1991           0.160312              0.697961
# 2     Afghanistan  AFG  1992           0.160135              0.698107
# 3     Afghanistan  AFG  1993           0.160037              0.698257
# 4     Afghanistan  AFG  1994           0.160022              0.698469
# ...           ...  ...   ...                ...                   ...
# 5483     Zimbabwe  ZWE  2013           0.155670              0.607993
# 5484     Zimbabwe  ZWE  2014           0.155993              0.608610
# 5485     Zimbabwe  ZWE  2015           0.156465              0.609363
# 5486     Zimbabwe  ZWE  2016           0.157111              0.610234
# 5487     Zimbabwe  ZWE  2017           0.157963              0.611242
#
#       Eating disorders (%)  Anxiety disorders (%)  Drug use disorders (%)  \
# ...

# %%
lst = psy['Drug use disorders (%)'].unique().tolist()

min(lst)
# Out:
# 0.38365

# %%
IF [Depression (%)] <= 2.77 THEN 'Muy baja'   
ELSEIF [Depression (%)] <= 3.41 THEN 'Baja' 
ELSEIF [Depression (%)] <= 4.05 THEN 'Medio-baja'
ELSEIF [Depression (%)] <= 4.69 THEN 'Medio'
ELSEIF [Depression (%)] <= 5.33 THEN 'Medio-alta'
ELSEIF [Depression (%)] <= 5.97 THEN 'Alta'
ELSE THEN 'Muy alta'
END

# %%
6.60
2.13
DEPRESION 
0,64

2.13 - 2.77 muy baja
2.77 - 3.41 baja
3.41 - 4.05 media-baja
4.05 - 4.69 media
4.69 - 5.33 media-alta
5.33 - 5.97 alta
5.97 - 6.60 muy alta

CONSUMO ALCOHOL
0.44
5.47

5.03%7 = 0.72

0.44 - 1.16 muy baja
1.16 - 1.88 baja
1.88 - 2.6 media-baja
2.6 - 3.32 media
3.32 - 4.04 media-alta
4.04 - 4.76 alta
4.76 - 5.47 muy alta

CONSUMO DROGAS
3.45
0.38

3.07%7= 0.44

0.38 - 0.82 muy baja
0.82 - 1.26 baja
1.26 - 1.7 media-baja
1.7 - 2.14 media
2.14 - 2.58 media-alta
2.58 - 3.02 alta
3.02 - 3.45 muy alta
