# %%
import os

current_directory = os.getcwd()
print("Directorio actual:", current_directory)
# Out:
# Directorio actual: /Users/davidusuariocasa/Desktop/Projects/Dashboard-Project

# %%
import pandas as pd

# %%
mental = pd.read_csv('/Users/davidusuariocasa/Desktop/mental.csv')
# Out:
# /var/folders/87/s4hx64fd369_w81yc2lyq29w0000gp/T/ipykernel_18006/3356450092.py:1: DtypeWarning: Columns (5,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   mental = pd.read_csv('/Users/davidusuariocasa/Desktop/mental.csv')

# %%
mental
# Out:
#          index       Entity Code  Year Schizophrenia (%) Bipolar disorder (%)  \
# 0            0  Afghanistan  AFG  1990           0.16056             0.697779
# 1            1  Afghanistan  AFG  1991          0.160312             0.697961
# 2            2  Afghanistan  AFG  1992          0.160135             0.698107
# 3            3  Afghanistan  AFG  1993          0.160037             0.698257
# 4            4  Afghanistan  AFG  1994          0.160022             0.698469
# ...        ...          ...  ...   ...               ...                  ...
# 108548  108548     Zimbabwe  ZWE  2013      303564.60359                  NaN
# 108549  108549     Zimbabwe  ZWE  2014     311665.769283                  NaN
# 108550  108550     Zimbabwe  ZWE  2015     320638.507158                  NaN
# 108551  108551     Zimbabwe  ZWE  2016     330437.353798                  NaN
# 108552  108552     Zimbabwe  ZWE  2017     340583.157405                  NaN
#
# ...

# %%
lst = mental['Year'].unique().tolist()
lst.sort()
lst
# Out:
# ['0',
#  '1',
#  '100',
#  '1000',
#  '1000 BCE',
#  '10000 BCE',
#  '1100',
#  '1200',
#  '1300',
#  '1400',
#  '1500',
#  '1600',
#  '1700',
#  '1710',
#  '1720',
#  '1730',
#  '1740',
#  '1750',
#  '1760',
#  '1770',
#  '1780',
#  '1790',
#  '1800',
#  '1801',
#  '1802',
#  '1803',
#  '1804',
#  '1805',
#  '1806',
#  '1807',
#  '1808',
#  '1809',
#  '1810',
#  '1811',
#  '1812',
#  '1813',
#  '1814',
#  '1815',
#  '1816',
#  '1817',
#  '1818',
#  '1819',
#  '1820',
#  '1821',
#  '1822',
#  '1823',
#  '1824',
#  '1825',
#  '1826',
#  '1827',
#  '1828',
#  '1829',
#  '1830',
#  '1831',
#  '1832',
#  '1833',
#  '1834',
#  '1835',
#  '1836',
#  '1837',
#  '1838',
#  '1839',
#  '1840',
#  '1841',
#  '1842',
#  '1843',
#  '1844',
#  '1845',
#  '1846',
#  '1847',
#  '1848',
#  '1849',
#  '1850',
#  '1851',
#  '1852',
#  '1853',
#  '1854',
#  '1855',
#  '1856',
#  '1857',
#  '1858',
#  '1859',
#  '1860',
#  '1861',
#  '1862',
#  '1863',
#  '1864',
#  '1865',
#  '1866',
#  '1867',
# ...

# %%
mental = mental[mental['Year'] == '2010']

mental1 = mental['Year'].unique().tolist()

mental.isna().sum()
# Out:
# index                          0
# Entity                         0
# Code                         150
# Year                           0
# Schizophrenia (%)             88
# Bipolar disorder (%)         319
# Eating disorders (%)         297
# Anxiety disorders (%)        781
# Drug use disorders (%)       781
# Depression (%)               781
# Alcohol use disorders (%)    781
# dtype: int64

# %%
suicide = pd.read_csv('/Users/davidusuariocasa/Desktop/suicide/crude suicide rates.csv')

# %%
suicide
# Out:
#       Unnamed: 0 Unnamed: 1  \
# 0        Country       Year
# 1    Afghanistan       2016
# 2    Afghanistan       2015
# 3    Afghanistan       2010
# 4    Afghanistan       2005
# ..           ...        ...
# 911     Zimbabwe       2016
# 912     Zimbabwe       2015
# 913     Zimbabwe       2010
# 914     Zimbabwe       2005
# 915     Zimbabwe       2000
#
#     Probability (%) of dying between age 30 and exact age 70 from any of cardiovascular disease, cancer, diabetes, or chronic respiratory disease  \
# 0                                           Both sexes
# 1                                                 29.8
# 2                                                 29.8
# 3                                                 31.7
# 4                                                 34.1
# ..                                                 ...
# 911                                               19.3
# 912                                               19.4
# ...

# %%
mortality = pd.read_csv('/Users/davidusuariocasa/Desktop/mortality/Adult mortality.csv')

# %%
mortality
# Out:
#        Unnamed: 0 Unnamed: 1  \
# 0         Country       Year
# 1     Afghanistan       2016
# 2     Afghanistan       2015
# 3     Afghanistan       2014
# 4     Afghanistan       2013
# ...           ...        ...
# 3107     Zimbabwe       2004
# 3108     Zimbabwe       2003
# 3109     Zimbabwe       2002
# 3110     Zimbabwe       2001
# 3111     Zimbabwe       2000
#
#      Adult mortality rate (probability of dying between 15 and 60 years per 1000 population)  \
# 0                                            Both sexes
# 1                                                   245
# 2                                                   233
# 3                                                   234
# 4                                                   235
# ...                                                 ...
# 3107                                                694
# 3108                                                697
# 3109                                                695
# ...
